# %%
text = "This is a text file"
key = text.split()
dict1 = {}

for i in key:
    dict1[i] = len(i)


print(dict1)
# Out:
# {'This': 4, 'is': 2, 'a': 1, 'text': 4, 'file': 4}

# %%
l1 = [1,2,3,4,7,9]
target = 11

for i in l1:
    for j in l1:
        if i+j == target:
            print([i,j])
        else:
            continue
# Out:
# [2, 9]
# [4, 7]
# [7, 4]
# [9, 2]

# %%
t1 = (1,2,3,4,5)
t1 = list(t1)
n = 3
rotate_left = t1[n:] + t1[:n]
rotate_right = t1[-n:] + t1[:-n]

# tuple(rotate_left)

rotate_right
# Out:
# [3, 4, 5, 1, 2]

# %%
def power_set(nums):
    if not nums:
        return [[]]
    smaller = power_set(nums[1:])
    return smaller + [[nums[0]] + s for s in smaller]

l1= [1, 2, 3,4]

# Step 1: Generate all subsets
subsets = power_set(l1)

# Step 2: Keep only subsets with even sum
even_subsets = [s for s in subsets if sum(s) % 2 == 0]

# Step 3: Sort so smallest groups come last
even_subsets.sort(key=len, reverse=True)

# Print result
for group in even_subsets:
    print(group)
# Out:
# [1, 2, 3, 4]
# [1, 3, 4]
# [1, 2, 3]
# [2, 4]
# [1, 3]
# [4]
# [2]
# []

# %%
import time

stock = {'Shirt':1200,'Shoes':3000,'Pants':1500}
items = list(stock.keys())
price = list(stock.values())

def menu():

    cart = []

    menu_str = '''
    Menu
    1. Show Shop
    2. Show Cart 
    3. Exit App\n'''

    
    if menu_input == 1:
        showShop()
        print("1st Input")

    for i  in menu_str:
        print(i,end = "")


    def showShop():
        print("Shop")
        for i in range(len(stock)):
            print(f"{i+1} {items[i]}  -  {price[i]}")
        print()

        def shopMenu():
            choice = int (input("Enter the number corresponding to the item you want to add to cart: "))
            cart.append(items[choice])

        shopMenu()
    menu_input = int(input("Enter the corresponding number with your choice: "))+




# stock = {'Shirt':10,'Shoes':3,'Pants':7}


# stock_name = showStock()

menu()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[54], line 47
#      37         shopMenu()
#      42 # stock = {'Shirt':10,'Shoes':3,'Pants':7}
#      43
#      44
#      45 # stock_name = showStock()
# ---> 47 menu()
#
# Cell In[54], line 20, in menu()
#      17 menu_input = int(input("Enter the corresponding number with your choice: "))
#      19 if menu_input == 1:
# ---> 20     showShop()
#      21     print("1st Input")
#      23 for i  in menu_str:
#
# UnboundLocalError: cannot access local variable 'showShop' where it is not associated with a value

# %%
len(price)
items = list(items)
print(items[0])
# Out:
# Shirt
