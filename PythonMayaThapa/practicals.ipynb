# %%
text = "This is a text file"
key = text.split()
dict1 = {}

for i in key:
    dict1[i] = len(i)


print(dict1)
# Out:
# {'This': 4, 'is': 2, 'a': 1, 'text': 4, 'file': 4}

# %%
l1 = [1,2,3,4,7,9]
target = 11

for i in l1:
    for j in l1:
        if i+j == target:
            print([i,j])
        else:
            continue
# Out:
# [2, 9]
# [4, 7]
# [7, 4]
# [9, 2]

# %%
t1 = (1,2,3,4,5)
t1 = list(t1)
n = 3
rotate_left = t1[n:] + t1[:n]
rotate_right = t1[-n:] + t1[:-n]

# tuple(rotate_left)

rotate_right
# Out:
# [3, 4, 5, 1, 2]

# %%
def power_set(nums):
    if not nums:
        return [[]]
    smaller = power_set(nums[1:])
    return smaller + [[nums[0]] + s for s in smaller]

l1= [1, 2, 3,4]

# Step 1: Generate all subsets
subsets = power_set(l1)

# Step 2: Keep only subsets with even sum
even_subsets = [s for s in subsets if sum(s) % 2 == 0]

# Step 3: Sort so smallest groups come last
even_subsets.sort(key=len, reverse=True)

# Print result
for group in even_subsets:
    print(group)
# Out:
# [1, 2, 3, 4]
# [1, 3, 4]
# [1, 2, 3]
# [2, 4]
# [1, 3]
# [4]
# [2]
# []

# %%
import time

stock = {'Shirt':1200,'Shoes':3000,'Pants':1500}
shit = list(stock.keys())
price = list(stock.values())
cart = []
total = 0
#Done prolly

def main_menu():
    #calc is short for calculator. I'm Just using slang guys.

    menu_str = '''
    Menu
    ------------
    1. Show Shop
    2. Show Cart 
    0. Exit App
    Enter 0 in the input box anywhere to go back one page.'''

    for i  in menu_str:
        print(i,end = "")

    menu_input = int(input("Enter the corresponding number with your choice: "))

    
    if menu_input == 1:
        shopMenu()

    elif menu_input == 2:
        cartMenu()

    elif menu_input == 0:

        bye_str = 'Exiting....'

        for j in bye_str:
            print(i,end = "")
            time.sleep(0.1)

def shopMenu():
    shop_str = '''
    Shop
    1. Add shit
    2. Go to Cart
    0. Back to Menu
    '''

    for i in shop_str:
        print(i,end = "")

    shop_choice = int (input("Enter the choice: "))
    
    if shop_choice == 1:
        showShop()

    elif shop_choice == 2:
        #Added Calc P.S NVM
        cartMenu()

    elif shop_choice == 0:
        main_menu()

    else:
        print("Invalid Input")
        shopMenu()

def showShop():
    print("Shop")
    print("-------")

    #whyyyy tf spaces???

    for i in range(len(stock)):
        print(f"{i+1} {shit[i]}  -  {price[i]}")

    addToCart = int(input("Enter the number corresponding to the desired item to add to cart: "))

    if addToCart == 0:
        shopMenu()

    elif addToCart <= len(shit):
        cart.append(shit[addToCart-1])
        print(cart)
        showShop()

    else:
        print("Invalid Choice")
        showShop()

    # shopMenu()

def cartMenu():
    cart_str = '''
    Cart
    -----------
    1. Checkout
    2. Add Items
    3. Clear Cart
    0. Back to Menu
    '''
    for i in cart_str:
        print(i,end = "")

    cartOption = int(input("Enter: "))

   


    if cartOption == 1:
        total = 0
        for i in range(len(cart)):
            for j in range(len(shit)):
                if cart[i] == shit[j]:  
                    total = total + price[j]
        nItems = len(cart)
        print(f"You have {nItems} in your cart and your total is {total}")

        #tf?


main_menu()
# Out:
#     Menu
#     ------------
#     1. Show Shop
#     2. Show Cart
#     0. Exit App
#
#     Enter 0 in the input box anywhere to go back one page.
#     Shop
#     1. Add Items
#     2. Go to Cart
#     0. Back to Menu
#     Shop
# -------
# 1 Shirt  -  1200
# 2 Shoes  -  3000
# 3 Pants  -  1500
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 121
#     117         nItems = len(cart)
#     118         print(f"You have {nItems} in your cart and your total is {total}")
# --> 121 main_menu()
#
# Cell In[8], line 27, in main_menu()
#      23 menu_input = int(input("Enter the corresponding number with your choice: "))
#      26 if menu_input == 1:
# ---> 27     shopMenu()
#      29 elif menu_input == 2:
#      30     cartMenu()
#
# Cell In[8], line 54, in shopMenu()
#      51 shop_choice = int (input("Enter the choice: "))
#      53 if shop_choice == 1:
# ---> 54     showShop()
#      56 elif shop_choice == 2:
#      57     #Added Calc
#      58     cartMenu()
#
# Cell In[8], line 74, in showShop()
#      71 for i in range(len(stock)):
#      72     print(f"{i+1} {items[i]}  -  {price[i]}")
# ---> 74 addToCart = int(input("Enter the number corresponding to the desired item to add to cart: "))
#      76 if addToCart == 0:
#      77     shopMenu()
#
# ValueError: invalid literal for int() with base 10: ''

# %%
len(price)
items = list(items)
print(items[0])
# Out:
# Shirt
